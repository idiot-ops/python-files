# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# as it can read above I imported the pandas, numpy and matplolib library to use for this assignment

# %%
Titles = pd.read_excel("Majors Titles and CIP Code.xlsx")
Titles
# Out:
#     Major Code                           Major Title CIP Code  \
# 0         AMES      Asian and Middle Eastern Studies   5.0103
# 1         ANTH                          Anthropology  45.0201
# 2        AN.EN  Anthropology & Environmental Studies  45.0299
# 3          ART                                   Art  50.0702
# 4        ART.H                         Art (History)  50.0703
# ..         ...                                   ...      ...
# 191      XSOPS                  Sociology-Psychology  45.9999
# 192      XSPUS                  Social Power in U.S.   5.0102
# 193      XUSPS          United States Policy Studies  45.1002
# 194      XWRES         Writing-Environmental Studies   23.999
# 195      XWRIT                               Writing   23.999
#
#                                           CIP Title xx.xx CIP Code  \
# 0                        Asian Studies/Civilization           5.01
# 1                                      Anthropology          45.02
# ...

# %% [markdown]
# Above I imported the Major titles excel data and here itt print some of the first and last ligns.

# %%
Grades = pd.read_excel("STEM Outcomes Grades 2002 - 2018 (anon).xlsx")
Grades
# Out:
#        Unnamed: 0           Student ID    Term  Academic Division Subject  \
# 0               0  6602904443393593344  2004SP                  2    THTR
# 1               1  6602904443393593344  2004FA                  2    THTR
# 2               2 -2039589217076994048  2005SP                  1    SSRA
# 3               3  5859295354834180096  2007FA                  2     MUS
# 4               4  5859295354834180096  2008SP                  2     MUS
# ...           ...                  ...     ...                ...     ...
# 75800       75800  1051871726049869952  2018SP                  1     POL
# 75801       75801  1051871726049869952  2018SP                  1     POL
# 75802       75802  1051871726049869952  2018SP                  1    SSRA
# 75803       75803  1051871726049869952  2018SP                  4    GENS
# 75804       75804  3609008991355611136  2018SP                  2     MUS
#
#       Course Number                    Course Title  Credits  Grade
# ...

# %% [markdown]
# Above I imported the Outcome Grades excel data and here itt print some of the first and last ligns.

# %%
Courses = pd.read_excel("STEM Outcomes Individual Data 2002 - 2018.xlsx")
Courses
# Out:
#       Unnamed: 0           Student ID Start Term   End Date Gender   Races  \
# 0              0   -93682460119976992     2002FA 2005-05-22      F      WH
# 1              1  6162924226455414784     2002FA 2004-02-02      F      WH
# 2              2 -8298550864126102528     2002FA 2006-05-21      F      WH
# 3              3  2287868604364420096     2002FA 2006-05-21      F      WH
# 4              4  5188866498457584640     2002FA 2007-05-20      F      WH
# ...          ...                  ...        ...        ...    ...     ...
# 6761        6761  8963912085140604928     2018SP        NaT      F     NaN
# 6762        6762 -1411874971982451968     2018SP        NaT      M      WH
# 6763        6763 -1268458029988883968     2018SP        NaT      F  BL, WH
# 6764        6764  1051871726049869952     2018SP        NaT      M      WH
# 6765        6765  3609008991355611136     2018SP        NaT      M     NaN
#
#      Ethnicity First Generation Major 1 Major 2 Major 3
# ...

# %% [markdown]
# Above I imported the STEM Outcomes excel data and here itt print some of the first and last ligns.

# %%
df.merge
# Out:
# <bound method DataFrame.merge of       Unnamed: 0           Student ID Start Term   End Date Gender   Races  \
# 0              0   -93682460119976992     2002FA 2005-05-22      F      WH
# 1              1  6162924226455414784     2002FA 2004-02-02      F      WH
# 2              2 -8298550864126102528     2002FA 2006-05-21      F      WH
# 3              3  2287868604364420096     2002FA 2006-05-21      F      WH
# 4              4  5188866498457584640     2002FA 2007-05-20      F      WH
# ...          ...                  ...        ...        ...    ...     ...
# 6761        6761  8963912085140604928     2018SP        NaT      F     NaN
# 6762        6762 -1411874971982451968     2018SP        NaT      M      WH
# 6763        6763 -1268458029988883968     2018SP        NaT      F  BL, WH
# 6764        6764  1051871726049869952     2018SP        NaT      M      WH
# 6765        6765  3609008991355611136     2018SP        NaT      M     NaN
#
# ...

# %% [markdown]
# here I df a merge function and called it so it provide some information about the data we will be merging below.

# %%
df_merge = pd.merge(Courses, Grades, on='Student ID', how='left')
df_mergeA = courses.merge(Grades, on="Student ID", how="left")

# %% [markdown]
# df_merge.head(200)

# %% [markdown]
# After merging the student ID within the courses and grades I get this table below which put all the student id in one column.

# %%
df_mergeA.head(100)
# Out:
#     Unnamed: 0_x           Student ID  Term_x  Academic Division_x Subject_x  \
# 0              0  6602904443393593344  2004SP                    2      THTR
# 1              0  6602904443393593344  2004SP                    2      THTR
# 2              1  6602904443393593344  2004FA                    2      THTR
# 3              1  6602904443393593344  2004FA                    2      THTR
# 4              2 -2039589217076994048  2005SP                    1      SSRA
# ..           ...                  ...     ...                  ...       ...
# 95            14  8098499497291757568  2005SP                    4      GENS
# 96            14  8098499497291757568  2005SP                    4      GENS
# 97            14  8098499497291757568  2005SP                    4      GENS
# 98            14  8098499497291757568  2005SP                    4      GENS
# 99            14  8098499497291757568  2005SP                    4      GENS
#
# ...

# %% [markdown]
#  here below I choose to merge the art major and it is divided into three ("major 1, major 2 na d major 3)
#  and call the function head to print the first 20 column and row of the data.

# %%
df_ART = df_merge[(df_merge["Major 1"]=="ART")|(df_merge["Major 2"]=="ART")|(df_merge["Major 3"]=="ART")]

# %%
df_ART.head()
# Out:
#     Unnamed: 0_x           Student ID Start Term   End Date Gender Races  \
# 43             4  5188866498457584640     2002FA 2007-05-20      F    WH
# 44             4  5188866498457584640     2002FA 2007-05-20      F    WH
# 45             4  5188866498457584640     2002FA 2007-05-20      F    WH
# 46             4  5188866498457584640     2002FA 2007-05-20      F    WH
# 47             4  5188866498457584640     2002FA 2007-05-20      F    WH
#
#    Ethnicity First Generation Major 1 Major 2 Major 3  Unnamed: 0_y    Term  \
# 43       NHS                N     ART     NaN     NaN            85  2002FA
# 44       NHS                N     ART     NaN     NaN            86  2002FA
# 45       NHS                N     ART     NaN     NaN            87  2002FA
# 46       NHS                N     ART     NaN     NaN            88  2002FA
# 47       NHS                N     ART     NaN     NaN            89  2002FA
#
# ...

# %% [markdown]
# Below I had call the academic division and equalize it with the art major to sort and return a new sorted list.

# %%
Academic_Division = df_ART["Course Title"].sort_values(ascending=False)

# %%
Academic_Division
# Out:
# 32198                         Yoga
# 4491            Women in Antiquity
# 7087            Women in Antiquity
# 4497                 Wind Ensemble
# 24548                Wind Ensemble
#                    ...
# 24167                 Accompanying
# 24173                 Accompanying
# 32470          Abnormal Psychology
# 41309         20th Century Physics
# 41312    20th C Physics Laboratory
# Name: Course Title, Length: 1598, dtype: object

# %%
class_participation = Academic_Division.value_counts().drop("Contemp Issues in Physics")
class_participation
# Out:
# Antiquity and Modernity           155
# Encounters                        140
# Beginning Drawing                  59
# Intro Art Hist & Vis Culture       40
# General Chemistry                  40
#                                  ...
# Intermediate Drawing                1
# Sportsmetrics, Cond for Women       1
# SS: Intermed Music Technology       1
# Mod and Contemp Art: 1924-PRES      1
# ST:Hist of the European Left        1
# Name: Course Title, Length: 374, dtype: int64

# %% [markdown]
# I call the class participation function to counts the contemp issues in physics from bigger to smaller.

# %%
courses = class_participation.sort_values(ascending=False)[:20].plot(kind="bar", color="blue", alpha=0.5, edgecolor = "green")
courses.set_xlabel('Majors')
courses.set_ylabel("Frequencey")
courses.set_title("The most taking for an ART majors")
courses

# %% [markdown]
# This is the first Histogramme i printed and here it listed from the most taken one to the smalles in the art majors fields. I put the frequency in the y axis and majors on the x axis.

# %%
merge1 = (df_merge['Major 1'] == "ART") | (df_merge['Major 2'] == "ART") | (df_merge['Major 3'] == "ART")
df_merge2 = df_merge.loc[(df_merge["Course Title"] == "Introduction to Fiction") & merge1, ["Grade", "Course Title", 'Major 1', 'Major 2', 'Major 3']]

# %%
df_merge2
# Out:
#        Grade             Course Title Major 1 Major 2 Major 3
# 4173     4.0  Introduction to Fiction     ART     NaN     NaN
# 4298     3.3  Introduction to Fiction     ART     NaN     NaN
# 10157    3.3  Introduction to Fiction     ART     NaN     NaN
# 14552    3.7  Introduction to Fiction     ART     NaN     NaN
# 16526    3.3  Introduction to Fiction     ART     NaN     NaN
# 32039    2.3  Introduction to Fiction     ART     NaN     NaN
# 33295    3.0  Introduction to Fiction     ART     NaN     NaN
# 33889    3.0  Introduction to Fiction     ART     NaN     NaN
# 36617    3.7  Introduction to Fiction     ART     NaN     NaN
# 48934    4.0  Introduction to Fiction     ART     NaN     NaN
# 51991    NaN  Introduction to Fiction     ART     NaN     NaN
# 54699    4.0  Introduction to Fiction     ART    PSYC     NaN
# 55226    3.0  Introduction to Fiction     ART     FMS     NaN

# %% [markdown]
# Above I use the merge 1 function and merge 2 to chech the combine majeor with art and those that had the introduction to fiction class.

# %%
df_merge1['Grade'].plot(kind="hist", alpha=0.1, color="red", edgecolor="purple", density=True)
plt.xlabel('Grade')
plt.ylabel('Frequency')
plt.title("Grades Distribution of Introduction to Fiction for an ART Major")
# Out:
# Text(0.5, 1.0, 'Grades Distribution of Introduction to Fiction for an ART Major')

# %% [markdown]
# frequency on the y axis and grade at the x axis I am still using the introduction to fiction to find the grade distribution woth the introduction to fiction.

# %%
merge2 = (df_merge["Major 1"] != "ART") | (df_merge["Major 2"] != "ART") | (df_merge["Major 3"] != "ART")
df_merge3 = df_merge.loc[(df_merge["Course Title"] == "Introduction to Fiction") & merge2, ["Grade", "Course Title", "Major 1", "Major 2", "Major 3"]]

# %%
df_merge3
# Out:
#        Grade             Course Title Major 1 Major 2 Major 3
# 92       3.7  Introduction to Fiction     SOC     NaN     NaN
# 353      3.7  Introduction to Fiction    CHEM     NaN     NaN
# 368      3.3  Introduction to Fiction    ENGL     NaN     NaN
# 573      NaN  Introduction to Fiction    FLLS     NaN     NaN
# 691      3.0  Introduction to Fiction    ENGL     NaN     NaN
# ...      ...                      ...     ...     ...     ...
# 70109    3.3  Introduction to Fiction     NaN     NaN     NaN
# 70120    3.0  Introduction to Fiction     NaN     NaN     NaN
# 70861    3.0  Introduction to Fiction     NaN     NaN     NaN
# 72870    0.0  Introduction to Fiction     NaN     NaN     NaN
# 74034    3.0  Introduction to Fiction     NaN     NaN     NaN
#
# [413 rows x 5 columns]

# %% [markdown]
# Here this function it also the same as the previous merge that I used above and  to find the courses distribution grade and the combine major. see above.

# %%
df_merge3["Grade"].plot(kind="hist", alpha=0.1, color="green", edgecolor="gray")
plt.xlabel("Grade")
plt.ylabel("Frequency")
plt.title("Grade per Distribution")
# Out:
# Text(0.5, 1.0, 'Grade per Distribution')

# %% [markdown]
# here I put a histogram to merge the grades from smaleer to greather.

# %%
df_MATH=df_merge[(df_merge["Major 1"]=="MATH")|(df_merge["Major 2"]=="MATH")|(df_merge["Major 3"]=="MATH")]

# %%
df_MATH
# Out:
#        Unnamed: 0_x           Student ID Start Term   End Date Gender Races  \
# 658              58 -4018711359628060160     2002FA 2006-05-21      F    WH
# 659              58 -4018711359628060160     2002FA 2006-05-21      F    WH
# 660              58 -4018711359628060160     2002FA 2006-05-21      F    WH
# 661              58 -4018711359628060160     2002FA 2006-05-21      F    WH
# 662              58 -4018711359628060160     2002FA 2006-05-21      F    WH
# ...             ...                  ...        ...        ...    ...   ...
# 56240          5087  2799018102186101760     2013FA 2017-05-21      M    AS
# 56241          5087  2799018102186101760     2013FA 2017-05-21      M    AS
# 56242          5087  2799018102186101760     2013FA 2017-05-21      M    AS
# 56243          5087  2799018102186101760     2013FA 2017-05-21      M    AS
# 56244          5087  2799018102186101760     2013FA 2017-05-21      M    AS
#
# ...

# %% [markdown]
# here I choose the second Major which is math

# %%
Academic_Division = df_MATH["Course Title"].sort_values(ascending=False)

# %%
Academic_Division2
# Out:
# 40542                          Zen
# 27175           Women in Antiquity
# 38952                Wind Ensemble
# 33075                Wind Ensemble
# 44482                Wind Ensemble
#                    ...
# 44481    20th C Physics Laboratory
# 16390    20th C Physics Laboratory
# 37520    20th C Physics Laboratory
# 27416    20th C Physics Laboratory
# 44062     19th C Europe, 1815-1914
# Name: Course Title, Length: 1041, dtype: object

# %%
class_participation2 = Academic_Division.value_counts().drop("Calculus III")
class_participation2
# Out:
# Encounters                 120
# Antiquity and Modernity     42
# Calculus Laboratory         38
# Calculus II                 28
# General Chemistry           27
#                           ...
# Europe Transformed           1
# Engineering Mathematics      1
# Biophysics                   1
# Elementary Statistics        1
# Biological Principles        1
# Name: Course Title, Length: 249, dtype: int64

# %% [markdown]
# and the courses title that i choose to is calculus III and with this one I will almost do the same as the one above(ARTH).

# %%
courses2 = class_participation2.sort_values(ascending=False)[:30].plot(kind="bar")
courses2.set_xlabel("Courses")
courses2.set_ylabel("Frequency")
courses2

# %% [markdown]
# I use the pyplot to sort out the classes from the one taking most to the one that is less taking.

# %%
merge3 = (df_merge["Major 1"] == "MATH") | (df_merge["Major 2"] == "MATH") | (df_merge["Major 3"] == "MATH")
df_merge4 = df_merge.loc[(df_merge["Course Title"] == "Calculus III") & merge3, ["Grade", "Course Title", "Major 1", "Major 2", "Major 3"]]

# %%
df_merge4
# Out:
#        Grade  Course Title Major 1 Major 2 Major 3
# 659      4.0  Calculus III    MATH    THTR     NaN
# 989      4.0  Calculus III    ECON    MATH     NaN
# 12773    4.0  Calculus III    ECON    MATH     NaN
# 16290    4.0  Calculus III    MATH    PHYS     NaN
# 16383    2.0  Calculus III    MATH    PHYS     NaN
# ...      ...           ...     ...     ...     ...
# 55666    4.0  Calculus III    MATH     NaN     NaN
# 55868    3.0  Calculus III    MATH     NaN     NaN
# 56087    3.0  Calculus III    MATH     NaN     NaN
# 56092    3.0  Calculus III    BBMB    MATH     NaN
# 56243    4.0  Calculus III    ECON    MATH     NaN
#
# [68 rows x 5 columns]

# %% [markdown]
# here I merge the class with a or condition meaning if the major 1 is nit included then it move next to the major 2 and so on to the third major. the | symbos is the or sign.

# %%
df_merge4["Grade"].plot(kind="hist", alpha=0.1, color="red", edgecolor="blue")
plt.xlabel("Grade")
plt.ylabel("Frequency")
plt.title("Grade per Distribution")
# Out:
# Text(0.5, 1.0, 'Grade per Distribution')

# %%
merge4 = (df_merge["Major 1"] != "MATH") | (df_merge["Major 2"] != "MATH") | (df_merge["Major 3"] != "MATH")
df_merge5 = df_merge.loc[(df_merge["Course Title"] == "Calculus III") & merge4, ["Grade", "Course Title", "Major 1", "Major 2", "Major 3"]]

# %%
df_merge5
# Out:
#        Grade  Course Title Major 1 Major 2 Major 3
# 229      2.7  Calculus III    CHEM     NaN     NaN
# 386      4.0  Calculus III   MTH.P     NaN     NaN
# 485      4.0  Calculus III   MTH.P    PHYS     NaN
# 659      4.0  Calculus III    MATH    THTR     NaN
# 732      3.7  Calculus III    CHEM     NaN     NaN
# ...      ...           ...     ...     ...     ...
# 74124    2.0  Calculus III     NaN     NaN     NaN
# 74151    4.0  Calculus III     NaN     NaN     NaN
# 74265    4.0  Calculus III     NaN     NaN     NaN
# 74308    3.3  Calculus III     NaN     NaN     NaN
# 74327    3.0  Calculus III     NaN     NaN     NaN
#
# [854 rows x 5 columns]

# %% [markdown]
# here I re-marged it again and this process keep on going as the question asked is to repeat the same fuction woth different subject and line so you can see that I assigned merge1, merge2, merge3 etc....

# %%
df_merge5["Grade"].plot(kind="hist", alpha=0.2, color="blue", edgecolor="yellow", density=True)
plt.xlabel("Grade")
plt.ylabel("Frequency")
plt.title("Grade per Distribution")
# Out:
# Text(0.5, 1.0, 'Grade per Distribution')

# %% [markdown]
# I here pyplot a histogram to plot the grade per distribution of the choosen course or subject.

# %%
df_MATH2=df_merge[(df_merge["Course Title"]=="Calculus Laboratory")|(df_merge["Course Title"]=="Calculus Laboratory")|(df_merge["Course Title"]=="Calculus Laboratory")]

# %%
df_MATH2
# Out:
#        Unnamed: 0_x           Student ID Start Term   End Date Gender Races  \
# 387              34 -7478759581835024384     2002FA 2006-05-21      F    WH
# 395              34 -7478759581835024384     2002FA 2006-05-21      F    WH
# 660              58 -4018711359628060160     2002FA 2006-05-21      F    WH
# 747              65 -4431352722159606784     2002FA 2006-05-21      F    AS
# 750              65 -4431352722159606784     2002FA 2006-05-21      F    AS
# ...             ...                  ...        ...        ...    ...   ...
# 66055          5980  6938222318015838208     2016FA        NaT      M    WH
# 67174          6082 -3456079322825500160     2016FA        NaT      F    WH
# 67590          6119 -8960677763730479104     2016FA        NaT      M    WH
# 69236          6266  -385864563643859712     2016FA        NaT      M    AS
# 69746          6313  2394971612845644800     2016FA        NaT      F    WH
#
# ...

# %% [markdown]
# here with the question4  i am repeating the same as the past but with different degree as you can see.

# %%
class_participation3 = df_MATH2[["Major 1", "Major 2", "Major 3"]].stack().value_counts().sort_values(ascending=False)
class_participation3
# Out:
# MATH     38
# ECON     22
# PHYS     17
# MA.PH    12
# MTH.A    11
# ASTR      9
# MTH.P     8
# PH.AS     6
# NMS       6
# PHIL      5
# BBMB      5
# EC.MA     5
# SOC       3
# CHEM      3
# ART       2
# EC.EN     2
# GE.AS     2
# PSYC      2
# BIOL      2
# REL       2
# GE.PH     2
# GNDS      2
# MUS.P     2
# GEOL      1
# ART.V     1
# RFS       1
# PH.PE     1
# THTR      1
# ANTH      1
# FMS       1
# MUS.T     1
# POL       1
# dtype: int64

# %% [markdown]
# here it i use the different majors to classify the one that has most been taking and as you can see there are math at the first with a 38

# %%
class_participation3 = class_participation3.sort_values(ascending=False)[:20].plot(kind="bar")
class_participation3.set_xlabel("Courses")
class_participation3.set_ylabel("Frequency")
class_participation3

# %% [markdown]
# In reference with the data above, I used them here to get a histogrammes of the math classification in term of classification.

# %%
merge5 = (df_merge["Major 1"] == "MATH") | (df_merge["Major 2"] == "MATH") | (df_merge["Major 3"] == "MATH")
df_merge6 = df_merge.loc[(df_merge["Subject"] == "MATH") & merge5, ["Grade", "Subject", "Major 1", "Major 2", "Major 3"]]
df_merge6
# Out:
#        Grade Subject Major 1 Major 2 Major 3
# 659      4.0    MATH    MATH    THTR     NaN
# 660      4.0    MATH    MATH    THTR     NaN
# 667      3.7    MATH    MATH    THTR     NaN
# 670      4.0    MATH    MATH    THTR     NaN
# 989      4.0    MATH    ECON    MATH     NaN
# ...      ...     ...     ...     ...     ...
# 56090    3.3    MATH    MATH     NaN     NaN
# 56092    3.0    MATH    BBMB    MATH     NaN
# 56106    2.0    MATH    BBMB    MATH     NaN
# 56236    3.0    MATH    ECON    MATH     NaN
# 56243    4.0    MATH    ECON    MATH     NaN
#
# [222 rows x 5 columns]

# %% [markdown]
# Here I merge the previous data by repeating the same process and I found this, but unfortunately I found the same result as before so i think it valid that the data are accurate.

# %% [markdown]
# i tried to uuse MATH2 as my variable but it did not work so I then replace it with MATH and I get this result above.

# %%
df_merge6["Grade"].plot(kind="hist", alpha=0.2, color="blue", edgecolor="black")
plt.xlabel("Grade")
plt.ylabel("Frequency")
plt.title("Grade per Distribution")
# Out:
# Text(0.5, 1.0, 'Grade Distribution')

# %% [markdown]
# this is the chart of the data above I used the same process and it give the Grede per distribution.

# %%
df_MATH3=df_merge[(df_merge["Course Title"]=="Calculus Laboratory")]

# %%
df_MATH3
# Out:
#        Unnamed: 0_x           Student ID Start Term   End Date Gender Races  \
# 387              34 -7478759581835024384     2002FA 2006-05-21      F    WH
# 395              34 -7478759581835024384     2002FA 2006-05-21      F    WH
# 660              58 -4018711359628060160     2002FA 2006-05-21      F    WH
# 747              65 -4431352722159606784     2002FA 2006-05-21      F    AS
# 750              65 -4431352722159606784     2002FA 2006-05-21      F    AS
# ...             ...                  ...        ...        ...    ...   ...
# 66055          5980  6938222318015838208     2016FA        NaT      M    WH
# 67174          6082 -3456079322825500160     2016FA        NaT      F    WH
# 67590          6119 -8960677763730479104     2016FA        NaT      M    WH
# 69236          6266  -385864563643859712     2016FA        NaT      M    AS
# 69746          6313  2394971612845644800     2016FA        NaT      F    WH
#
# ...

# %% [markdown]
# this is theMath 3 version with the repetition i used the same process as before just the different is that I use the Stack function and that function add to the sort of and clasify to the final classement of the data and the claculus laboratory.

# %%
class_participation4 = df_MATH2[["Major 1", "Major 2", "Major 3"]].stack().value_counts().sort_values(ascending=False)
class_participation4
# Out:
# MATH     38
# ECON     22
# PHYS     17
# MA.PH    12
# MTH.A    11
# ASTR      9
# MTH.P     8
# PH.AS     6
# NMS       6
# PHIL      5
# BBMB      5
# EC.MA     5
# SOC       3
# CHEM      3
# ART       2
# EC.EN     2
# GE.AS     2
# PSYC      2
# BIOL      2
# REL       2
# GE.PH     2
# GNDS      2
# MUS.P     2
# GEOL      1
# ART.V     1
# RFS       1
# PH.PE     1
# THTR      1
# ANTH      1
# FMS       1
# MUS.T     1
# POL       1
# dtype: int64

# %%
class_participation4 = class_participation4.sort_values(ascending=False)[:20].plot(kind="bar")
class_participation4.set_xlabel("Courses")
class_participation4.set_ylabel("Frequency")
class_participation4

# %% [markdown]
# this is the historgrammes of the above function.

# %%
df_linear=df_merge[(df_merge["Course Title"]=="Linear Algebra")]

# %%
df_linear
# Out:
#        Unnamed: 0_x           Student ID Start Term   End Date Gender Races  \
# 3658            321 -5844909246167711744     2002FA 2008-01-23      M    WH
# 5427            485  3931534365030350848     2003FA 2007-05-15      F    WH
# 7338            658   575381991749578816     2003FA 2007-05-15      M    AS
# 7602            682 -5979017242298556416     2003FA 2005-05-22      M   NaN
# 8458            760 -7724219498033929216     2003FA 2007-05-15      M    WH
# ...             ...                  ...        ...        ...    ...   ...
# 73459          6661  5888068413255879680     2017FA        NaT      M    AS
# 73550          6669 -8392993443025742848     2017FA        NaT      M    WH
# 73589          6672  7007196348403191808     2017FA        NaT      F    BL
# 73983          6709 -7044535554221142016     2017FA        NaT      F    AS
# 74157          6726  4971633472316557312     2017FA        NaT      F    WH
#
# ...

# %% [markdown]
# I started this linear equation to analyses the intercept and data relation between the majors.

# %%
class_participation4 = df_linear[["Major 1", "Major 2", "Major 3"]].stack().value_counts().sort_values(ascending=False)
class_participation4
# Out:
# MATH     25
# PHYS      7
# EC.MA     5
# ECON      4
# BBMB      4
# MTH.P     3
# BIOL      2
# NMS       2
# PH.AS     2
# PSYC      1
# BI.EN     1
# SPAN      1
# PHIL      1
# MA.PH     1
# FREN      1
# ART       1
# CHEM      1
# dtype: int64

# %% [markdown]
# here I find that the list of the major from the most taking to the less

# %%
class_participation4 = class_participation4.sort_values(ascending=False)[:20].plot(kind="bar")
class_participation4.set_xlabel("Courses")
class_participation4.set_ylabel("Frequency")
class_participation4

# %% [markdown]
# I use the classification and pyplot the same as I use it before so here is the chart that I found. it show the classification of the kpst and less taking majors.

# %%
merge7 = (df_merge['Major 1'] == "FREN")
df_merge7 = df_merge.loc[(df_merge['Subject'] == 'FREN') & merge7, ['Grade', 'Subject', 'Major 1', 'Major 2', 'Major 3']]
df_merge7
# Out:
#        Grade Subject Major 1 Major 2 Major 3
# 27649    3.0    FREN    FREN    HIST     NaN
# 27654    3.0    FREN    FREN    HIST     NaN
# 28198    4.0    FREN    FREN     NaN     NaN
# 28203    3.7    FREN    FREN     NaN     NaN
# 28398    4.0    FREN    FREN     NaN     NaN
# 28402    3.3    FREN    FREN     NaN     NaN
# 29310    4.0    FREN    FREN     NaN     NaN
# 29317    4.0    FREN    FREN     NaN     NaN
# 30947    4.0    FREN    FREN     NaN     NaN
# 30956    4.0    FREN    FREN     NaN     NaN
# 31682    4.0    FREN    FREN     NaN     NaN
# 31688    3.7    FREN    FREN     NaN     NaN
# 32224    4.0    FREN    FREN    THTR     NaN
# 32231    3.7    FREN    FREN    THTR     NaN
# 34118    3.7    FREN    FREN     NaN     NaN
# 43339    4.0    FREN    FREN     NaN     NaN
# 43341    4.0    FREN    FREN     NaN     NaN
# 43346    4.0    FREN    FREN     NaN     NaN
# 43413    3.3    FREN    FREN   GER.S     NaN
# 43421    3.3    FREN    FREN   GER.S     NaN
# ...

# %% [markdown]
# I used the french major for further anakysis and found out that some people combine it with ohter subject such as math.

# %%
df_merge7['Grade'].plot(kind='hist', alpha=0.5, color='blue', edgecolor='black')
plt.xlabel('Grade')
plt.ylabel('Frequency')
plt.title('Grade per istribution')
# Out:
# Text(0.5, 1.0, 'Grade per istribution')

# %% [markdown]
# this is the chart of the frech major and as you can see show a very inequal data. from the grade ranging frrom 3.0 to 4.0 meaning student grades are more higher in frenc than other majors as math for xample.

# %% [markdown]
# Number 7:
#
# From here the above and beyond start.

# %%
df_merge[["Course Number", "First Generation"]].corr()
df_merge
# Out:
#        Unnamed: 0_x           Student ID Start Term   End Date Gender Races  \
# 0                 0   -93682460119976992     2002FA 2005-05-22      F    WH
# 1                 0   -93682460119976992     2002FA 2005-05-22      F    WH
# 2                 0   -93682460119976992     2002FA 2005-05-22      F    WH
# 3                 0   -93682460119976992     2002FA 2005-05-22      F    WH
# 4                 0   -93682460119976992     2002FA 2005-05-22      F    WH
# ...             ...                  ...        ...        ...    ...   ...
# 74496          6764  1051871726049869952     2018SP        NaT      M    WH
# 74497          6764  1051871726049869952     2018SP        NaT      M    WH
# 74498          6764  1051871726049869952     2018SP        NaT      M    WH
# 74499          6764  1051871726049869952     2018SP        NaT      M    WH
# 74500          6765  3609008991355611136     2018SP        NaT      M   NaN
#
# ...

# %% [markdown]
# I use the some variable from the forst data to merge the data and this what I found.

# %%
df_merge["Course"] = df_merge["Subject"] +  df_merge["Course Number"].apply(str)
df_merge
# Out:
#        Unnamed: 0_x           Student ID Start Term   End Date Gender Races  \
# 0                 0   -93682460119976992     2002FA 2005-05-22      F    WH
# 1                 0   -93682460119976992     2002FA 2005-05-22      F    WH
# 2                 0   -93682460119976992     2002FA 2005-05-22      F    WH
# 3                 0   -93682460119976992     2002FA 2005-05-22      F    WH
# 4                 0   -93682460119976992     2002FA 2005-05-22      F    WH
# ...             ...                  ...        ...        ...    ...   ...
# 74496          6764  1051871726049869952     2018SP        NaT      M    WH
# 74497          6764  1051871726049869952     2018SP        NaT      M    WH
# 74498          6764  1051871726049869952     2018SP        NaT      M    WH
# 74499          6764  1051871726049869952     2018SP        NaT      M    WH
# 74500          6765  3609008991355611136     2018SP        NaT      M   NaN
#
# ...

# %% [markdown]
# I continue merging and as I introduce with the majors and courses.

# %%
df_econ_majors = df_merge[(df_merge['Major 1'] =="ECON" ) | (df_merge['Major 2'] =="ECON" ) | (df_merge['Major 3'] =="ECON" )]
df_econ_majors
# Out:
#        Unnamed: 0_x           Student ID Start Term   End Date Gender Races  \
# 745              65 -4431352722159606784     2002FA 2006-05-21      F    AS
# 746              65 -4431352722159606784     2002FA 2006-05-21      F    AS
# 747              65 -4431352722159606784     2002FA 2006-05-21      F    AS
# 748              65 -4431352722159606784     2002FA 2006-05-21      F    AS
# 749              65 -4431352722159606784     2002FA 2006-05-21      F    AS
# ...             ...                  ...        ...        ...    ...   ...
# 61275          5541  1859890314540195072     2015FA 2017-05-21      M    WH
# 61276          5541  1859890314540195072     2015FA 2017-05-21      M    WH
# 61277          5541  1859890314540195072     2015FA 2017-05-21      M    WH
# 61278          5541  1859890314540195072     2015FA 2017-05-21      M    WH
# 61279          5541  1859890314540195072     2015FA 2017-05-21      M    WH
#
# ...

# %% [markdown]
# I define a function for the econ major and there is data found.

# %%
len(df_econ_majors["Student ID"].unique())
# Out:
# 294

# %% [markdown]
# I use len to solve for the lend of the unique student ID

# %%
course_counts = df_merge["Course"].value_counts()
course_counts
# Out:
# GENS145    6599
# GENS146    6454
# CHEM135    2102
# CHEM125    2066
# PSYC110    1820
#            ...
# FREN328       1
# BBMB324       1
# SPAN442       1
# PSYC357       1
# ARTH353       1
# Name: Course, Length: 1429, dtype: int64

# %% [markdown]
# Here I count the counts function to merge the course variable, and here you can see the data.

# %%
course_counts[course_counts>400].plot(kind='bar')

# %% [markdown]
# here is the chart i found when count the course that are most taking as you can see GENS occupied the first two row

# %%
math225_grades = df_merge["Grade"][df_merge["Course"] == 'MATH225'].dropna()
math225_grades
# Out:
# 229      2.7
# 386      4.0
# 485      4.0
# 659      4.0
# 732      3.7
#         ...
# 74124    2.0
# 74151    4.0
# 74265    4.0
# 74308    3.3
# 74327    3.0
# Name: Grade, Length: 849, dtype: float64

# %%
math225_grades.plot(kind='hist', rwidth=0.95)

# %% [markdown]
# hyere I merge with the grades and plot a histogram and that show the range of the higest that student get ton the lowest whoich from 4 to 0.5.
